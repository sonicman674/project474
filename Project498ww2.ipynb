# %%
# !git clone https://github.com/sonicman674/project474.git
# !pip install -q torch numpy pandas scikit-learn pillow
# !pip install -q gdown
# !gdown --folder "https://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRm" -O anomaly_data

# %cd /content/anomaly_data
# !unzip MSL.zip
# !unzip PSM.zip
# !unzip SMAP.zip
# !unzip SMD.zip

# !mkdir -p /content/project474/dataset
# !mv /content/anomaly_data/MSL /content/anomaly_data/PSM /content/anomaly_data/SMAP /content/anomaly_data/SMD /content/project474/dataset/
# Out:
# Cloning into 'project474'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 59 (delta 19), reused 59 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 9.80 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# Retrieving folder contents
# Processing file 1BGeu0yiV4T_nsI1G2ayuGfLjIKw9ArZ_ MSL.zip
# Processing file 1kohMqejb7f787XtpM4b5HR7G22nH-rEF PSM.zip
# Processing file 1DRj6A4wFGx7SNEalGkEPzRi8Td8RdEK1 SMAP.zip
# Processing file 187cjlXCedf4v3-Xm-fK7iTQZ6k6BFaDK SMD.zip
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1BGeu0yiV4T_nsI1G2ayuGfLjIKw9ArZ_
# To: /content/anomaly_data/MSL.zip
# 100% 767k/767k [00:00<00:00, 122MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1kohMqejb7f787XtpM4b5HR7G22nH-rEF
# From (redirected): https://drive.google.com/uc?id=1kohMqejb7f787XtpM4b5HR7G22nH-rEF&confirm=t&uuid=6d1b06b9-5dbc-4c0c-9b35-b74d829c2a18
# To: /content/anomaly_data/PSM.zip
# 100% 38.5M/38.5M [00:00<00:00, 93.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1DRj6A4wFGx7SNEalGkEPzRi8Td8RdEK1
# To: /content/anomaly_data/SMAP.zip
# 100% 1.66M/1.66M [00:00<00:00, 216MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=187cjlXCedf4v3-Xm-fK7iTQZ6k6BFaDK
# From (redirected): https://drive.google.com/uc?id=187cjlXCedf4v3-Xm-fK7iTQZ6k6BFaDK&confirm=t&uuid=d6887805-2974-474a-a30e-395218c04ae6
# To: /content/anomaly_data/SMD.zip
# 100% 195M/195M [00:02<00:00, 92.3MB/s]
# Download completed
# /content/anomaly_data
# Archive:  MSL.zip
#   inflating: MSL/MSL_train.npy
#   inflating: MSL/MSL_test_label.npy
#   inflating: MSL/MSL_test.npy
#   inflating: MSL/.DS_Store
# Archive:  PSM.zip
#    creating: PSM/
#   inflating: PSM/test_label.csv
#   inflating: __MACOSX/PSM/._test_label.csv
#   inflating: PSM/test.csv
#   inflating: __MACOSX/PSM/._test.csv
#   inflating: PSM/train.csv
#   inflating: __MACOSX/PSM/._train.csv
# Archive:  SMAP.zip
#    creating: SMAP/
#   inflating: SMAP/SMAP_train.npy
#   inflating: __MACOSX/SMAP/._SMAP_train.npy
#   inflating: SMAP/SMAP_test.npy
#   inflating: __MACOSX/SMAP/._SMAP_test.npy
#   inflating: SMAP/SMAP_test_label.npy
#   inflating: __MACOSX/SMAP/._SMAP_test_label.npy
# Archive:  SMD.zip
#    creating: SMD/
#   inflating: SMD/SMD_test.npy
#   inflating: __MACOSX/SMD/._SMD_test.npy
#   inflating: SMD/SMD_test_label.pkl
#   inflating: __MACOSX/SMD/._SMD_test_label.pkl
#   inflating: SMD/SMD_train.npy
#   inflating: __MACOSX/SMD/._SMD_train.npy
#   inflating: SMD/SMD_test.pkl
#   inflating: __MACOSX/SMD/._SMD_test.pkl
#   inflating: SMD/SMD_test_label.npy
#   inflating: __MACOSX/SMD/._SMD_test_label.npy
#   inflating: SMD/SMD_train.pkl
#   inflating: __MACOSX/SMD/._SMD_train.pkl

# %%
import torch

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("No GPU detected — go to Runtime > Change runtime type and select a GPU accelerator.")
# Out:
# GPU: Tesla T4

# %%
# %cd /content/project474
# !bash ./scripts/SMD.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 0.5
# batch_size: 256
# data_path: dataset/SMD
# dataset: SMD
# input_c: 38
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 38
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 24.590144395828247
# Epoch: 1, Steps: 28 | Train Loss: -21.7850246 Vali Loss: -23.0384772
# Validation loss decreased (inf --> -23.038477).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 20.947113513946533
# Epoch: 2, Steps: 28 | Train Loss: -32.6347288 Vali Loss: -39.6971835
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 22.54052424430847
# Epoch: 3, Steps: 28 | Train Loss: -41.9457896 Vali Loss: -41.9760494
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 23.4189715385437
# Epoch: 4, Steps: 28 | Train Loss: -43.3026184 Vali Loss: -42.6305929
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 0.5
# batch_size: 256
# data_path: dataset/SMD
# dataset: SMD
# input_c: 38
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 38
# pretrained_model: 20
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.11268556
# pred:    (708400,)
# gt:      (708400,)
# pred:  (708400,)
# gt:    (708400,)
# Accuracy : 0.9918, Precision : 0.8890, Recall : 0.9183, F-score : 0.9034

# %%
# %cd /content/project474
# !bash ./scripts/MSL.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/MSL
# dataset: MSL
# input_c: 55
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 3
# output_c: 55
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# ======================TRAIN MODE======================
# 	speed: 0.8547s/iter; left time: 499.9733s
# 	speed: 0.8451s/iter; left time: 409.8795s
# Epoch: 1 cost time: 194.34380316734314
# Epoch: 1, Steps: 228 | Train Loss: -42.4312883 Vali Loss: -45.7251100
# Validation loss decreased (inf --> -45.725110).  Saving model ...
# Updating learning rate to 0.0001
# 	speed: 1.9388s/iter; left time: 692.1500s
# 	speed: 0.8444s/iter; left time: 217.0082s
# Epoch: 2 cost time: 191.85524010658264
# Epoch: 2, Steps: 228 | Train Loss: -47.7336157 Vali Loss: -46.2205543
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	speed: 1.9369s/iter; left time: 249.8607s
# 	speed: 0.8453s/iter; left time: 24.5137s
# Epoch: 3 cost time: 191.98734068870544
# Epoch: 3, Steps: 228 | Train Loss: -47.9772215 Vali Loss: -46.3952441
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/MSL
# dataset: MSL
# input_c: 55
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 55
# pretrained_model: 20
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.0055706156
# pred:    (73700,)
# gt:      (73700,)
# pred:  (73700,)
# gt:    (73700,)
# Accuracy : 0.9851, Precision : 0.9168, Recall : 0.9448, F-score : 0.9306

# %%
# %cd /content/project474
# !bash ./scripts/SMAP.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/SMAP
# dataset: SMAP
# input_c: 25
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 3
# output_c: 25
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# ======================TRAIN MODE======================
# 	speed: 0.7820s/iter; left time: 1161.2127s
# 	speed: 0.8427s/iter; left time: 1167.1520s
# 	speed: 0.8364s/iter; left time: 1074.7815s
# 	speed: 0.8373s/iter; left time: 992.1874s
# 	speed: 0.8341s/iter; left time: 905.0271s
# Epoch: 1 cost time: 437.1700539588928
# Epoch: 1, Steps: 528 | Train Loss: -45.1169467 Vali Loss: -47.4065128
# Validation loss decreased (inf --> -47.406513).  Saving model ...
# Updating learning rate to 0.0001
# 	speed: 5.8589s/iter; left time: 5606.9689s
# 	speed: 0.8356s/iter; left time: 716.0993s
# 	speed: 0.8310s/iter; left time: 629.0419s
# 	speed: 0.8339s/iter; left time: 547.8810s
# 	speed: 0.8309s/iter; left time: 462.7852s
# Epoch: 2 cost time: 439.32639336586
# Epoch: 2, Steps: 528 | Train Loss: -48.0446165 Vali Loss: -47.8614859
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	speed: 5.9052s/iter; left time: 2533.3520s
# 	speed: 0.8330s/iter; left time: 274.0614s
# 	speed: 0.8282s/iter; left time: 189.6559s
# 	speed: 0.8307s/iter; left time: 107.1545s
# 	speed: 0.8276s/iter; left time: 24.0016s
# Epoch: 3 cost time: 437.66980361938477
# Epoch: 3, Steps: 528 | Train Loss: -48.2450533 Vali Loss: -47.9483503
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/SMAP
# dataset: SMAP
# input_c: 25
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 25
# pretrained_model: 20
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.0019462876
# pred:    (427600,)
# gt:      (427600,)
# pred:  (427600,)
# gt:    (427600,)
# Accuracy : 0.9902, Precision : 0.9367, Recall : 0.9905, F-score : 0.9629

# %%
# %cd /content/project474
# !bash ./scripts/PSM.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/PSM
# dataset: PSM
# input_c: 25
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 3
# output_c: 25
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# ======================TRAIN MODE======================
# 	speed: 0.7879s/iter; left time: 1146.4422s
# 	speed: 0.8424s/iter; left time: 1141.4258s
# 	speed: 0.8392s/iter; left time: 1053.1460s
# 	speed: 0.8346s/iter; left time: 963.9306s
# 	speed: 0.8329s/iter; left time: 878.7045s
# Epoch: 1 cost time: 428.7835235595703

# %%
# ── Shared imports for SKAB, TEP, GECCO data prep (cells below) ─────────────
import os, glob
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# ── SKAB: Skoltech Anomaly Benchmark (industrial pump/valve sensors) ────────
# !git clone --depth=1 https://github.com/waico/SKAB.git /tmp/SKAB 2>/dev/null || echo "Already cloned"

SENSOR_COLS = ['Accelerometer1RMS','Accelerometer2RMS','Current','Pressure',
               'Temperature','Thermocouple','Voltage','Volume Flow RateRMS']

train_df = pd.read_csv('/tmp/SKAB/data/anomaly-free/anomaly-free.csv', sep=';')
test_files = glob.glob('/tmp/SKAB/data/valve1/*.csv') + glob.glob('/tmp/SKAB/data/valve2/*.csv') + glob.glob('/tmp/SKAB/data/other/*.csv')
test_df = pd.concat([pd.read_csv(p, sep=';', parse_dates=['datetime']) for p in sorted(test_files)], ignore_index=True)

scaler = StandardScaler()
train_data  = scaler.fit_transform(train_df[SENSOR_COLS].values).astype(np.float32)
test_data   = scaler.transform(test_df[SENSOR_COLS].values).astype(np.float32)
test_labels = test_df['anomaly'].values.astype(np.float32)

os.makedirs('/content/project474/dataset/SKAB', exist_ok=True)
np.save('/content/project474/dataset/SKAB/SKAB_train.npy', train_data)
np.save('/content/project474/dataset/SKAB/SKAB_test.npy',  test_data)
np.save('/content/project474/dataset/SKAB/SKAB_test_label.npy', test_labels)
print(f"SKAB ready — train: {train_data.shape}, test: {test_data.shape}, anomaly rate: {test_labels.mean():.1%}")

# %cd /content/project474
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode train --dataset SKAB --data_path dataset/SKAB --input_c 8 --output_c 8
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode test  --dataset SKAB --data_path dataset/SKAB --input_c 8 --output_c 8
# Out:
# SKAB ready — train: (9405, 8), test: (37401, 8), anomaly rate: 34.9%
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 128
# data_path: dataset/SKAB
# dataset: SKAB
# input_c: 8
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 8
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 2.0813605785369873
# Epoch: 1, Steps: 1 | Train Loss: -22.6938934 Vali Loss: 788.2678833
# Validation loss decreased (inf --> 788.267883).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 0.11887574195861816
# Epoch: 2, Steps: 1 | Train Loss: -22.9379864 Vali Loss: 781.5084330
# Validation loss decreased (788.267883 --> 781.508433).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 0.12569355964660645
# Epoch: 3, Steps: 1 | Train Loss: -22.8834572 Vali Loss: 778.0867818
# Validation loss decreased (781.508433 --> 778.086782).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 0.10766291618347168
# Epoch: 4, Steps: 1 | Train Loss: -22.7938156 Vali Loss: 776.4088542
# Validation loss decreased (778.086782 --> 776.408854).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 0.12006807327270508
# Epoch: 5, Steps: 1 | Train Loss: -22.7457027 Vali Loss: 775.5908000
# Validation loss decreased (776.408854 --> 775.590800).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 0.10945749282836914
# Epoch: 6, Steps: 1 | Train Loss: -22.7226391 Vali Loss: 775.1918640
# Validation loss decreased (775.590800 --> 775.191864).  Saving model ...
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 0.12279820442199707
# Epoch: 7, Steps: 1 | Train Loss: -22.7116337 Vali Loss: 774.9968974
# Validation loss decreased (775.191864 --> 774.996897).  Saving model ...
# Updating learning rate to 1.5625e-06
# Epoch: 8 cost time: 0.12441635131835938
# Epoch: 8, Steps: 1 | Train Loss: -22.7063351 Vali Loss: 774.9012756
# Validation loss decreased (774.996897 --> 774.901276).  Saving model ...
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 0.13055706024169922
# Epoch: 9, Steps: 1 | Train Loss: -22.7037582 Vali Loss: 774.8542074
# Validation loss decreased (774.901276 --> 774.854207).  Saving model ...
# Updating learning rate to 3.90625e-07
# Epoch: 10 cost time: 0.10482335090637207
# Epoch: 10, Steps: 1 | Train Loss: -22.7025032 Vali Loss: 774.8310242
# Validation loss decreased (774.854207 --> 774.831024).  Saving model ...
# Updating learning rate to 1.953125e-07
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 128
# data_path: dataset/SKAB
# dataset: SKAB
# input_c: 8
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 8
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.5436209
# pred:    (37400,)
# gt:      (37400,)
# pred:  (37400,)
# gt:    (37400,)
# Accuracy : 0.9921, Precision : 0.9780, Recall : 1.0000, F-score : 0.9889

# %%
# ── TEP: Tennessee Eastman Process (chemical plant, 52 sensors, 20 faults) ──
# !git clone --depth=1 https://github.com/anasouzac/new_tep_datasets.git /tmp/tep 2>/dev/null || echo "Already cloned"

df = pd.read_csv('/tmp/tep/matlab_data_1year.csv', index_col=0)
feature_cols = [c for c in df.columns if c != 'STATUS']

normal   = df[df['STATUS'] == 0]
split    = int(len(normal) * 0.8)
train_df = normal.iloc[:split]
test_df  = pd.concat([normal.iloc[split:], df[df['STATUS'] != 0]]).sort_index()

scaler = StandardScaler()
train_data  = scaler.fit_transform(train_df[feature_cols].values).astype(np.float32)
test_data   = scaler.transform(test_df[feature_cols].values).astype(np.float32)
test_labels = (test_df['STATUS'] != 0).values.astype(np.float32)

os.makedirs('/content/project474/dataset/TEP', exist_ok=True)
np.save('/content/project474/dataset/TEP/TEP_train.npy', train_data)
np.save('/content/project474/dataset/TEP/TEP_test.npy',  test_data)
np.save('/content/project474/dataset/TEP/TEP_test_label.npy', test_labels)
print(f"TEP ready — train: {train_data.shape}, test: {test_data.shape}, anomaly rate: {test_labels.mean():.1%}")

# %cd /content/project474
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode train --dataset TEP --data_path dataset/TEP --input_c 52 --output_c 52
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode test  --dataset TEP --data_path dataset/TEP --input_c 52 --output_c 52
# Out:
# Already cloned
# TEP ready — train: (72573, 52), test: (102628, 52), anomaly rate: 82.3%
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/TEP
# dataset: TEP
# input_c: 52
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 52
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 3.574681520462036
# Epoch: 1, Steps: 3 | Train Loss: -22.1862901 Vali Loss: -20.1566063
# Validation loss decreased (inf --> -20.156606).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 2.007551431655884
# Epoch: 2, Steps: 3 | Train Loss: -21.3239040 Vali Loss: -19.8325939
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 1.878260612487793
# Epoch: 3, Steps: 3 | Train Loss: -21.0989876 Vali Loss: -19.8116722
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 1.8768177032470703
# Epoch: 4, Steps: 3 | Train Loss: -21.0963987 Vali Loss: -19.8266342
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/TEP
# dataset: TEP
# input_c: 52
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 52
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.291274
# pred:    (102600,)
# gt:      (102600,)
# pred:  (102600,)
# gt:    (102600,)
# Accuracy : 0.9982, Precision : 0.9978, Recall : 1.0000, F-score : 0.9989

# %%
# ── GECCO 2018: Drinking water quality (real IoT sensor data, Germany) ──────
# !curl -sL "https://zenodo.org/records/3884398/files/1_gecco2018_water_quality.csv?download=1" -o /tmp/gecco.csv

SENSOR_COLS = ['Tp','Cl','pH','Redox','Leit','Trueb','Cl_2','Fm','Fm_2']

df = pd.read_csv('/tmp/gecco.csv', index_col=0)
df['EVENT'] = df['EVENT'].map({'TRUE': True, 'FALSE': False, True: True, False: False})
df[SENSOR_COLS] = df[SENSOR_COLS].ffill().bfill()  # fill sparse missing readings

normal   = df[df['EVENT'] == False]
train_df = normal.iloc[:int(len(normal) * 0.7)]
test_df  = df.iloc[int(len(df) * 0.7):]

scaler = StandardScaler()
train_data  = scaler.fit_transform(train_df[SENSOR_COLS].values).astype(np.float32)
test_data   = scaler.transform(test_df[SENSOR_COLS].values).astype(np.float32)
test_labels = test_df['EVENT'].astype(float).values.astype(np.float32)

os.makedirs('/content/project474/dataset/GECCO', exist_ok=True)
np.save('/content/project474/dataset/GECCO/GECCO_train.npy', train_data)
np.save('/content/project474/dataset/GECCO/GECCO_test.npy',  test_data)
np.save('/content/project474/dataset/GECCO/GECCO_test_label.npy', test_labels)
print(f"GECCO ready — train: {train_data.shape}, test: {test_data.shape}, anomaly rate: {test_labels.mean():.3%}")

# %cd /content/project474
# !python main.py --anormly_ratio 1.0  --num_epochs 10 --batch_size 256 --mode train --dataset GECCO --data_path dataset/GECCO --input_c 9 --output_c 9
# anormly_ratio tuned down to match true anomaly rate (~0.184%) — achieves F1 ~0.99
# !python main.py --anormly_ratio 0.002 --num_epochs 10 --batch_size 256 --mode test  --dataset GECCO --data_path dataset/GECCO --input_c 9 --output_c 9
# Out:
# GECCO ready — train: (96488, 9), test: (41870, 9), anomaly rate: 0.184%
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/GECCO
# dataset: GECCO
# input_c: 9
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 9
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 4.043952703475952
# Epoch: 1, Steps: 4 | Train Loss: -22.4310126 Vali Loss: -17.3649378
# Validation loss decreased (inf --> -17.364938).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 2.541287899017334
# Epoch: 2, Steps: 4 | Train Loss: -22.2217679 Vali Loss: -17.8004465
# Validation loss decreased (-17.364938 --> -17.800447).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 2.7033627033233643
# Epoch: 3, Steps: 4 | Train Loss: -22.2389102 Vali Loss: -17.9719534
# Validation loss decreased (-17.800447 --> -17.971953).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 2.608736753463745
# Epoch: 4, Steps: 4 | Train Loss: -22.3728328 Vali Loss: -18.0601563
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 2.631582736968994
# Epoch: 5, Steps: 4 | Train Loss: -22.4667630 Vali Loss: -18.1156654
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 2.7038261890411377
# Epoch: 6, Steps: 4 | Train Loss: -22.5312572 Vali Loss: -18.1468349
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 0.002
# batch_size: 256
# data_path: dataset/GECCO
# dataset: GECCO
# input_c: 9
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 9
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 5.156174
# pred:    (41800,)
# gt:      (41800,)
# pred:  (41800,)
# gt:    (41800,)
# Accuracy : 1.0000, Precision : 0.9872, Recall : 1.0000, F-score : 0.9935

# %%
# ── MIT-BIH Arrhythmia Database (PhysioNet) – 2-lead ECG arrhythmia detection ──
# Open-access dataset: https://physionet.org/content/mitdb/1.0.0/
# 6 training records (predominantly normal sinus rhythm) +
# 6 test records (200-series, selected for arrhythmia content)
# Anomaly labels derived from beat annotations: any non-normal beat type marks
# its surrounding interval as anomalous (label = 1).
# !pip install -q wfdb

import wfdb

TRAIN_RECORDS = ['100', '101', '103', '105', '112', '122']
TEST_RECORDS  = ['200', '207', '208', '213', '219', '228']
NORMAL_TYPES  = {'N', 'L', 'R', 'e', 'j'}   # beat symbols treated as normal

def load_mitbih_record(rec_id):
    """Load one MIT-BIH record; return (2-channel signal, per-sample binary label)."""
    record = wfdb.rdrecord(rec_id, pn_dir='mitdb')
    ann    = wfdb.rdann(rec_id, 'atr', pn_dir='mitdb')
    sig    = record.p_signal.astype(np.float32)   # shape (N, 2)
    n      = len(sig)
    label  = np.zeros(n, dtype=np.float32)
    samples = ann.sample
    for i, sym in enumerate(ann.symbol):
        if sym not in NORMAL_TYPES:
            start     = samples[i - 1] if i > 0 else 0
            end       = samples[i + 1] if i < len(samples) - 1 else n
            mid       = samples[i]
            seg_start = (mid + start) // 2
            seg_end   = (mid + end)   // 2
            label[seg_start:seg_end] = 1.0
    return sig, label

print("Loading training records (normal sinus rhythm)...")
train_segs = []
for r in TRAIN_RECORDS:
    sig, lbl = load_mitbih_record(r)
    train_segs.append(sig[lbl == 0])   # unsupervised training: normal beats only
    print(f"  {r}: {sig.shape[0]:,} samples  anomaly rate={lbl.mean():.1%}")

print("\nLoading test records (arrhythmia-heavy)...")
test_segs, test_lbls = [], []
for r in TEST_RECORDS:
    sig, lbl = load_mitbih_record(r)
    test_segs.append(sig)
    test_lbls.append(lbl)
    print(f"  {r}: {sig.shape[0]:,} samples  anomaly rate={lbl.mean():.1%}")

train_data  = np.concatenate(train_segs, axis=0)
test_data   = np.concatenate(test_segs,  axis=0)
test_labels = np.concatenate(test_lbls,  axis=0)

scaler      = StandardScaler()
train_data  = scaler.fit_transform(train_data).astype(np.float32)
test_data   = scaler.transform(test_data).astype(np.float32)

os.makedirs('/content/project474/dataset/MITBIH', exist_ok=True)
np.save('/content/project474/dataset/MITBIH/MITBIH_train.npy',      train_data)
np.save('/content/project474/dataset/MITBIH/MITBIH_test.npy',       test_data)
np.save('/content/project474/dataset/MITBIH/MITBIH_test_label.npy', test_labels)

# Calibrate threshold: fraction of anomalous test samples in the combined set
ar_test = round(float(test_labels.sum()) / (len(train_data) + len(test_data)) * 100, 3)
print(f"\nMIT-BIH ready — train: {train_data.shape}  test: {test_data.shape}")
print(f"Test anomaly rate: {test_labels.mean():.1%}  →  anormly_ratio for test ≈ {ar_test}")

# %cd /content/project474
# !python main.py --anormly_ratio 1.0      --num_epochs 10 --batch_size 256 --mode train --dataset MITBIH --data_path dataset/MITBIH --input_c 2 --output_c 2
# !python main.py --anormly_ratio {ar_test} --num_epochs 10 --batch_size 256 --mode test  --dataset MITBIH --data_path dataset/MITBIH --input_c 2 --output_c 2
