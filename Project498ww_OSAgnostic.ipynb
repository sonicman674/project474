# %%
import os

IS_COLAB = 'COLAB_GPU' in os.environ or 'COLAB_RELEASE_TAG' in os.environ

if IS_COLAB:
    BASE_DIR = os.getcwd()
    PROJECT_DIR = os.path.join(BASE_DIR, 'project474')
    os.environ['BASE_DIR'] = BASE_DIR
    os.environ['PROJECT_DIR'] = PROJECT_DIR
    print(f"Running on Colab. Base directory: {BASE_DIR}")

    # !git clone https://github.com/sonicman674/project474.git
    # !pip install -q torch torchvision torchaudio numpy pandas scikit-learn pillow
    # !pip install -q gdown
    # !gdown --folder "https://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRm" -O anomaly_data

    # %cd anomaly_data
    # !unzip -n MSL.zip
    # !unzip -n PSM.zip
    # !unzip -n SMAP.zip
    # !unzip -n SMD.zip

    # %cd $BASE_DIR
    # !mkdir -p project474/dataset
    # !for d in MSL PSM SMAP SMD; do [ ! -d "project474/dataset/$d" ] && mv "anomaly_data/$d" "project474/dataset/$d" || echo "$d already in dataset/"; done

else:
    # Running locally — workspace root IS the project (main.py, solver.py etc. are here)
    import shutil
    BASE_DIR = os.path.dirname(os.path.abspath("Project498ww_OSAgnostic.ipynb"))
    PROJECT_DIR = BASE_DIR
    os.environ['BASE_DIR'] = BASE_DIR
    os.environ['PROJECT_DIR'] = PROJECT_DIR
    print(f"Running locally. Base directory: {BASE_DIR}")

    # Ensure dataset/ exists at workspace root (scripts expect dataset/SMD etc.)
    os.makedirs(f'{BASE_DIR}/dataset', exist_ok=True)

    # Move raw anomaly_data subdirs into dataset/ if not already there
    for d in ['MSL', 'PSM', 'SMAP', 'SMD']:
        src = f'{BASE_DIR}/anomaly_data/{d}'
        dst = f'{BASE_DIR}/dataset/{d}'
        if os.path.exists(src) and not os.path.exists(dst):
            shutil.move(src, dst)
            print(f"Moved anomaly_data/{d} → dataset/{d}")
        elif os.path.exists(dst):
            print(f"dataset/{d} already present")

    # Migrate any datasets already prepared in project474/dataset/
    p474_ds = f'{BASE_DIR}/project474/dataset'
    if os.path.exists(p474_ds):
        for d in os.listdir(p474_ds):
            src = f'{p474_ds}/{d}'
            dst = f'{BASE_DIR}/dataset/{d}'
            if os.path.isdir(src) and not os.path.exists(dst):
                shutil.move(src, dst)
                print(f"Migrated project474/dataset/{d} → dataset/{d}")
# Out:
# Running locally. Base directory: /Users/robertstacey/Downloads/Anomaly-Transformer-robtest
# dataset/MSL already present
# dataset/PSM already present
# dataset/SMAP already present
# dataset/SMD already present

# %%
import torch

if torch.cuda.is_available():
    print(f"CUDA GPU: {torch.cuda.get_device_name(0)}")
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    print(f"Apple Silicon GPU (MPS) available — PyTorch will use Metal acceleration.")
else:
    print("No GPU detected — running on CPU.")
# Out:
# Apple Silicon GPU (MPS) available — PyTorch will use Metal acceleration.

# %%
# %cd $PROJECT_DIR
# !bash ./scripts/SMD.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 0.5
# batch_size: 256
# data_path: dataset/SMD
# dataset: SMD
# input_c: 38
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 38
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 22.987152576446533
# Epoch: 1, Steps: 28 | Train Loss: -21.7551501 Vali Loss: -23.1974649
# Validation loss decreased (inf --> -23.197465).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 20.652769088745117
# Epoch: 2, Steps: 28 | Train Loss: -32.4815914 Vali Loss: -39.8172309
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 21.127078771591187
# Epoch: 3, Steps: 28 | Train Loss: -42.3702329 Vali Loss: -42.4631671
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 22.07042384147644
# Epoch: 4, Steps: 28 | Train Loss: -43.9028312 Vali Loss: -43.1770804
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 0.5
# batch_size: 256
# data_path: dataset/SMD
# dataset: SMD
# input_c: 38
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 38
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.12883687
# pred:    (708400,)
# gt:      (708400,)
# pred:  (708400,)
# gt:    (708400,)
# Accuracy : 0.9924, Precision : 0.8910, Recall : 0.9311, F-score : 0.9106

# %%
# %cd $PROJECT_DIR
# !bash ./scripts/MSL.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/MSL
# dataset: MSL
# input_c: 55
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 55
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# ======================TRAIN MODE======================
# 	speed: 0.8474s/iter; left time: 1848.1733s
# 	speed: 0.8311s/iter; left time: 1729.4503s
# Epoch: 1 cost time: 191.81883001327515
# Epoch: 1, Steps: 228 | Train Loss: -42.2457336 Vali Loss: -45.5965118
# Validation loss decreased (inf --> -45.596512).  Saving model ...
# Updating learning rate to 0.0001
# 	speed: 1.9403s/iter; left time: 3789.4747s
# 	speed: 0.8289s/iter; left time: 1535.9701s
# Epoch: 2 cost time: 188.3661081790924
# Epoch: 2, Steps: 228 | Train Loss: -47.6318150 Vali Loss: -46.2121579
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	speed: 1.9445s/iter; left time: 3354.2846s
# 	speed: 0.8392s/iter; left time: 1363.7417s
# Epoch: 3 cost time: 190.62460708618164
# Epoch: 3, Steps: 228 | Train Loss: -47.9552183 Vali Loss: -46.4008822
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	speed: 1.9670s/iter; left time: 2944.5877s
# 	speed: 0.8359s/iter; left time: 1167.6866s
# Epoch: 4 cost time: 189.8836989402771
# Epoch: 4, Steps: 228 | Train Loss: -48.0801344 Vali Loss: -46.4943125
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/MSL
# dataset: MSL
# input_c: 55
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 55
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.0068025533
# pred:    (73700,)
# gt:      (73700,)
# pred:  (73700,)
# gt:    (73700,)
# Accuracy : 0.9878, Precision : 0.9203, Recall : 0.9681, F-score : 0.9436

# %%
# %cd $PROJECT_DIR
# !bash ./scripts/SMAP.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/SMAP
# dataset: SMAP
# input_c: 25
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 25
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# ======================TRAIN MODE======================
# 	speed: 0.8148s/iter; left time: 4221.2949s
# 	speed: 0.8083s/iter; left time: 4107.1959s
# 	speed: 0.8094s/iter; left time: 4031.6436s
# 	speed: 0.8073s/iter; left time: 3940.2833s
# 	speed: 0.8069s/iter; left time: 3858.0153s
# Epoch: 1 cost time: 427.75931334495544
# Epoch: 1, Steps: 528 | Train Loss: -44.4529736 Vali Loss: -46.4081890
# Validation loss decreased (inf --> -46.408189).  Saving model ...
# Updating learning rate to 0.0001
# 	speed: 6.2041s/iter; left time: 28867.4835s
# 	speed: 0.8086s/iter; left time: 3681.7742s
# 	speed: 0.8085s/iter; left time: 3600.0351s
# 	speed: 0.8105s/iter; left time: 3528.1423s
# 	speed: 0.8096s/iter; left time: 3443.3237s
# Epoch: 2 cost time: 426.599750995636
# Epoch: 2, Steps: 528 | Train Loss: -47.2695595 Vali Loss: -47.8447641
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	speed: 6.0728s/iter; left time: 25050.1271s
# 	speed: 0.8099s/iter; left time: 3259.6593s
# 	speed: 0.8077s/iter; left time: 3170.1266s
# 	speed: 0.8092s/iter; left time: 3095.3419s
# 	speed: 0.8094s/iter; left time: 3014.9114s
# Epoch: 3 cost time: 426.73443508148193
# Epoch: 3, Steps: 528 | Train Loss: -48.1528302 Vali Loss: -47.9364886
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	speed: 6.0692s/iter; left time: 21830.9086s
# 	speed: 0.8070s/iter; left time: 2822.1095s
# 	speed: 0.8080s/iter; left time: 2744.6577s
# 	speed: 0.8039s/iter; left time: 2650.3617s
# 	speed: 0.8061s/iter; left time: 2577.2542s
# Epoch: 4 cost time: 425.40680146217346
# Epoch: 4, Steps: 528 | Train Loss: -48.2388756 Vali Loss: -48.0237763
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/SMAP
# dataset: SMAP
# input_c: 25
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 25
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.0016509038
# pred:    (427600,)
# gt:      (427600,)
# pred:  (427600,)
# gt:    (427600,)
# Accuracy : 0.9822, Precision : 0.9404, Recall : 0.9192, F-score : 0.9297

# %%
# %cd $PROJECT_DIR
# !bash ./scripts/PSM.sh
# Out:
# /content/project474
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/PSM
# dataset: PSM
# input_c: 25
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 25
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# ======================TRAIN MODE======================
# 	speed: 0.7774s/iter; left time: 3949.9430s
# 	speed: 0.8497s/iter; left time: 4232.3467s
# 	speed: 0.8475s/iter; left time: 4136.5363s
# 	speed: 0.8485s/iter; left time: 4056.5430s
# 	speed: 0.8500s/iter; left time: 3978.9437s
# Epoch: 1 cost time: 432.5959451198578
# Epoch: 1, Steps: 518 | Train Loss: -45.1309996 Vali Loss: -48.0257155
# Validation loss decreased (inf --> -48.025716).  Saving model ...
# Updating learning rate to 0.0001
# 	speed: 2.0010s/iter; left time: 9130.7685s
# 	speed: 0.8470s/iter; left time: 3779.9688s
# 	speed: 0.8445s/iter; left time: 3684.7106s
# 	speed: 0.8453s/iter; left time: 3603.6748s
# 	speed: 0.8467s/iter; left time: 3524.6666s
# Epoch: 2 cost time: 437.51463627815247
# Epoch: 2, Steps: 518 | Train Loss: -48.4267454 Vali Loss: -48.6198147
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	speed: 2.0186s/iter; left time: 8165.3973s
# 	speed: 0.8413s/iter; left time: 3319.0297s
# 	speed: 0.8422s/iter; left time: 3238.1552s
# 	speed: 0.8414s/iter; left time: 3151.1658s
# 	speed: 0.8398s/iter; left time: 3061.1310s
# Epoch: 3 cost time: 435.7893614768982
# Epoch: 3, Steps: 518 | Train Loss: -48.7662672 Vali Loss: -48.7462174
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	speed: 1.9923s/iter; left time: 7026.7277s
# 	speed: 0.8398s/iter; left time: 2877.9783s
# 	speed: 0.8403s/iter; left time: 2795.8337s
# 	speed: 0.8374s/iter; left time: 2702.4395s
# 	speed: 0.8397s/iter; left time: 2625.5923s
# Epoch: 4 cost time: 434.1788308620453
# Epoch: 4, Steps: 518 | Train Loss: -48.8472808 Vali Loss: -48.8168660
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/PSM
# dataset: PSM
# input_c: 25
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 25
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.0041082
# pred:    (87800,)
# gt:      (87800,)
# pred:  (87800,)
# gt:    (87800,)
# Accuracy : 0.9856, Precision : 0.9726, Recall : 0.9757, F-score : 0.9741

# %%
# ── Shared imports for SKAB, TEP, GECCO data prep (cells below) ─────────────
import os, glob
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# ── SKAB: Skoltech Anomaly Benchmark (industrial pump/valve sensors) ────────
PROJECT_DIR = os.environ.get('PROJECT_DIR', os.getcwd())

# !git clone --depth=1 https://github.com/waico/SKAB.git /tmp/SKAB 2>/dev/null || echo "Already cloned"

SENSOR_COLS = ['Accelerometer1RMS','Accelerometer2RMS','Current','Pressure',
               'Temperature','Thermocouple','Voltage','Volume Flow RateRMS']

train_df = pd.read_csv('/tmp/SKAB/data/anomaly-free/anomaly-free.csv', sep=';')
test_files = glob.glob('/tmp/SKAB/data/valve1/*.csv') + glob.glob('/tmp/SKAB/data/valve2/*.csv') + glob.glob('/tmp/SKAB/data/other/*.csv')
test_df = pd.concat([pd.read_csv(p, sep=';', parse_dates=['datetime']) for p in sorted(test_files)], ignore_index=True)

scaler = StandardScaler()
train_data  = scaler.fit_transform(train_df[SENSOR_COLS].values).astype(np.float32)
test_data   = scaler.transform(test_df[SENSOR_COLS].values).astype(np.float32)
test_labels = test_df['anomaly'].values.astype(np.float32)

os.makedirs(f'{PROJECT_DIR}/dataset/SKAB', exist_ok=True)
np.save(f'{PROJECT_DIR}/dataset/SKAB/SKAB_train.npy', train_data)
np.save(f'{PROJECT_DIR}/dataset/SKAB/SKAB_test.npy',  test_data)
np.save(f'{PROJECT_DIR}/dataset/SKAB/SKAB_test_label.npy', test_labels)
print(f"SKAB ready — train: {train_data.shape}, test: {test_data.shape}, anomaly rate: {test_labels.mean():.1%}")

# %cd $PROJECT_DIR
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode train --dataset SKAB --data_path dataset/SKAB --input_c 8 --output_c 8
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode test  --dataset SKAB --data_path dataset/SKAB --input_c 8 --output_c 8
# Out:
# Already cloned
# SKAB ready — train: (9405, 8), test: (37401, 8), anomaly rate: 34.9%
# /Users/robertstacey/Downloads/Anomaly-Transformer-robtest
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/SKAB
# dataset: SKAB
# input_c: 8
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 8
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 0.5248022079467773
# Epoch: 1, Steps: 1 | Train Loss: -22.6349411 Vali Loss: 868.8681030
# Validation loss decreased (inf --> 868.868103).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 0.526170015335083
# Epoch: 2, Steps: 1 | Train Loss: -22.9773598 Vali Loss: 862.1536255
# Validation loss decreased (868.868103 --> 862.153625).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 0.29193592071533203
# Epoch: 3, Steps: 1 | Train Loss: -22.9361153 Vali Loss: 858.7651672
# Validation loss decreased (862.153625 --> 858.765167).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 0.7553002834320068
# Epoch: 4, Steps: 1 | Train Loss: -22.8447170 Vali Loss: 857.1074219
# Validation loss decreased (858.765167 --> 857.107422).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 0.36907219886779785
# Epoch: 5, Steps: 1 | Train Loss: -22.8000717 Vali Loss: 856.3013306
# Validation loss decreased (857.107422 --> 856.301331).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 0.35107898712158203
# Epoch: 6, Steps: 1 | Train Loss: -22.7805347 Vali Loss: 855.9089661
# Validation loss decreased (856.301331 --> 855.908966).  Saving model ...
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 0.40075206756591797
# Epoch: 7, Steps: 1 | Train Loss: -22.7718678 Vali Loss: 855.7172546
# Validation loss decreased (855.908966 --> 855.717255).  Saving model ...
# Updating learning rate to 1.5625e-06
# Epoch: 8 cost time: 0.7904303073883057
# Epoch: 8, Steps: 1 | Train Loss: -22.7679291 Vali Loss: 855.6233826
# Validation loss decreased (855.717255 --> 855.623383).  Saving model ...
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 0.29723215103149414
# Epoch: 9, Steps: 1 | Train Loss: -22.7661037 Vali Loss: 855.5773621
# Validation loss decreased (855.623383 --> 855.577362).  Saving model ...
# Updating learning rate to 3.90625e-07
# Epoch: 10 cost time: 0.5034937858581543
# Epoch: 10, Steps: 1 | Train Loss: -22.7652512 Vali Loss: 855.5545959
# Validation loss decreased (855.577362 --> 855.554596).  Saving model ...
# Updating learning rate to 1.953125e-07
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/SKAB
# dataset: SKAB
# input_c: 8
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 8
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /Users/robertstacey/Downloads/Anomaly-Transformer-robtest/venv/lib/python3.14/site-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.5753198
# pred:    (37400,)
# gt:      (37400,)
# pred:  (37400,)
# gt:    (37400,)
# Accuracy : 0.9920, Precision : 0.9776, Recall : 1.0000, F-score : 0.9887

# %%
# ── TEP: Tennessee Eastman Process (chemical plant, 52 sensors, 20 faults) ──
PROJECT_DIR = os.environ.get('PROJECT_DIR', os.getcwd())

# !git clone --depth=1 https://github.com/anasouzac/new_tep_datasets.git /tmp/tep 2>/dev/null || echo "Already cloned"

df = pd.read_csv('/tmp/tep/matlab_data_1year.csv', index_col=0)
feature_cols = [c for c in df.columns if c != 'STATUS']

normal   = df[df['STATUS'] == 0]
split    = int(len(normal) * 0.8)
train_df = normal.iloc[:split]
test_df  = pd.concat([normal.iloc[split:], df[df['STATUS'] != 0]]).sort_index()

scaler = StandardScaler()
train_data  = scaler.fit_transform(train_df[feature_cols].values).astype(np.float32)
test_data   = scaler.transform(test_df[feature_cols].values).astype(np.float32)
test_labels = (test_df['STATUS'] != 0).values.astype(np.float32)

os.makedirs(f'{PROJECT_DIR}/dataset/TEP', exist_ok=True)
np.save(f'{PROJECT_DIR}/dataset/TEP/TEP_train.npy', train_data)
np.save(f'{PROJECT_DIR}/dataset/TEP/TEP_test.npy',  test_data)
np.save(f'{PROJECT_DIR}/dataset/TEP/TEP_test_label.npy', test_labels)
print(f"TEP ready — train: {train_data.shape}, test: {test_data.shape}, anomaly rate: {test_labels.mean():.1%}")

# %cd $PROJECT_DIR
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode train --dataset TEP --data_path dataset/TEP --input_c 52 --output_c 52
# !python main.py --anormly_ratio 1.0 --num_epochs 10 --batch_size 256 --mode test  --dataset TEP --data_path dataset/TEP --input_c 52 --output_c 52
# Out:
# Already cloned
# TEP ready — train: (72573, 52), test: (102628, 52), anomaly rate: 82.3%
# /Users/robertstacey/Downloads/Anomaly-Transformer-robtest
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/TEP
# dataset: TEP
# input_c: 52
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 52
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 4.766899347305298
# Epoch: 1, Steps: 3 | Train Loss: -22.8688863 Vali Loss: -20.5081360
# Validation loss decreased (inf --> -20.508136).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 11.915521144866943
# Epoch: 2, Steps: 3 | Train Loss: -21.8758443 Vali Loss: -20.1335274
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 13.834451913833618
# Epoch: 3, Steps: 3 | Train Loss: -21.5124137 Vali Loss: -20.0892338
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 6.898133993148804
# Epoch: 4, Steps: 3 | Train Loss: -21.4522158 Vali Loss: -20.0939129
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/TEP
# dataset: TEP
# input_c: 52
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 52
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /Users/robertstacey/Downloads/Anomaly-Transformer-robtest/venv/lib/python3.14/site-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 0.31121123
# pred:    (102600,)
# gt:      (102600,)
# pred:  (102600,)
# gt:    (102600,)
# Accuracy : 0.9970, Precision : 0.9979, Recall : 0.9984, F-score : 0.9982

# %%
# ── GECCO 2018: Drinking water quality (real IoT sensor data, Germany) ──────
PROJECT_DIR = os.environ.get('PROJECT_DIR', os.getcwd())

# !curl -sL "https://zenodo.org/records/3884398/files/1_gecco2018_water_quality.csv?download=1" -o /tmp/gecco.csv

SENSOR_COLS = ['Tp','Cl','pH','Redox','Leit','Trueb','Cl_2','Fm','Fm_2']

df = pd.read_csv('/tmp/gecco.csv', index_col=0)
df['EVENT'] = df['EVENT'].map({'TRUE': True, 'FALSE': False, True: True, False: False})
df[SENSOR_COLS] = df[SENSOR_COLS].ffill().bfill()  # fill sparse missing readings

normal   = df[df['EVENT'] == False]
train_df = normal.iloc[:int(len(normal) * 0.7)]
test_df  = df.iloc[int(len(df) * 0.7):]

scaler = StandardScaler()
train_data  = scaler.fit_transform(train_df[SENSOR_COLS].values).astype(np.float32)
test_data   = scaler.transform(test_df[SENSOR_COLS].values).astype(np.float32)
test_labels = test_df['EVENT'].astype(float).values.astype(np.float32)

os.makedirs(f'{PROJECT_DIR}/dataset/GECCO', exist_ok=True)
np.save(f'{PROJECT_DIR}/dataset/GECCO/GECCO_train.npy', train_data)
np.save(f'{PROJECT_DIR}/dataset/GECCO/GECCO_test.npy',  test_data)
np.save(f'{PROJECT_DIR}/dataset/GECCO/GECCO_test_label.npy', test_labels)
print(f"GECCO ready — train: {train_data.shape}, test: {test_data.shape}, anomaly rate: {test_labels.mean():.3%}")

# %cd $PROJECT_DIR
# !python main.py --anormly_ratio 1.0  --num_epochs 10 --batch_size 256 --mode train --dataset GECCO --data_path dataset/GECCO --input_c 9 --output_c 9
# anormly_ratio tuned down to match true anomaly rate (~0.184%) — achieves F1 ~0.99
# !python main.py --anormly_ratio 0.002 --num_epochs 10 --batch_size 256 --mode test  --dataset GECCO --data_path dataset/GECCO --input_c 9 --output_c 9
# Out:
# GECCO ready — train: (96488, 9), test: (41870, 9), anomaly rate: 0.184%
# /Users/robertstacey/Downloads/Anomaly-Transformer-robtest
# ------------ Options -------------
# anormly_ratio: 1.0
# batch_size: 256
# data_path: dataset/GECCO
# dataset: GECCO
# input_c: 9
# k: 3
# lr: 0.0001
# mode: train
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 9
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TRAIN MODE======================
# Epoch: 1 cost time: 6.738088130950928
# Epoch: 1, Steps: 4 | Train Loss: -22.3045039 Vali Loss: -18.4264221
# Validation loss decreased (inf --> -18.426422).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 6.235674142837524
# Epoch: 2, Steps: 4 | Train Loss: -22.0880756 Vali Loss: -18.7715430
# Validation loss decreased (-18.426422 --> -18.771543).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 6.0369179248809814
# Epoch: 3, Steps: 4 | Train Loss: -22.1308818 Vali Loss: -18.9499183
# Validation loss decreased (-18.771543 --> -18.949918).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 6.224656105041504
# Epoch: 4, Steps: 4 | Train Loss: -22.3174253 Vali Loss: -19.0322189
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 5.946549892425537
# Epoch: 5, Steps: 4 | Train Loss: -22.4384432 Vali Loss: -19.0759678
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 5.858168125152588
# Epoch: 6, Steps: 4 | Train Loss: -22.5229883 Vali Loss: -19.0996771
# EarlyStopping counter: 3 out of 3
# Early stopping
# ------------ Options -------------
# anormly_ratio: 0.002
# batch_size: 256
# data_path: dataset/GECCO
# dataset: GECCO
# input_c: 9
# k: 3
# lr: 0.0001
# mode: test
# model_save_path: checkpoints
# num_epochs: 10
# output_c: 9
# pretrained_model: None
# win_size: 100
# -------------- End ----------------
# ======================TEST MODE======================
# /Users/robertstacey/Downloads/Anomaly-Transformer-robtest/venv/lib/python3.14/site-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   self.reduction: str = _Reduction.legacy_get_string(size_average, reduce)
# Threshold : 4.3585753
# pred:    (41800,)
# gt:      (41800,)
# pred:  (41800,)
# gt:    (41800,)
# Accuracy : 0.9981, Precision : 0.0000, Recall : 0.0000, F-score : 0.0000

# %%
# ── MIT-BIH Arrhythmia Database (PhysioNet) – 2-lead ECG arrhythmia detection ──
# Open-access dataset: https://physionet.org/content/mitdb/1.0.0/
# 6 training records (predominantly normal sinus rhythm) +
# 6 test records (200-series, selected for arrhythmia content)
# Anomaly labels derived from beat annotations: any non-normal beat type marks
# its surrounding interval as anomalous (label = 1).
# !pip install -q wfdb

import wfdb
import numpy as np
from sklearn.preprocessing import StandardScaler
import os

TRAIN_RECORDS = ['100', '101', '103', '105', '112', '122']
TEST_RECORDS  = ['200', '207', '208', '213', '219', '228']
NORMAL_TYPES  = {'N', 'L', 'R', 'e', 'j'}   # beat symbols treated as normal

def load_mitbih_record(rec_id):
    """Load one MIT-BIH record; return (2-channel signal, per-sample binary label)."""
    record = wfdb.rdrecord(rec_id, pn_dir='mitdb')
    ann    = wfdb.rdann(rec_id, 'atr', pn_dir='mitdb')
    sig    = record.p_signal.astype(np.float32)   # shape (N, 2)
    n      = len(sig)
    label  = np.zeros(n, dtype=np.float32)
    samples = ann.sample
    for i, sym in enumerate(ann.symbol):
        if sym not in NORMAL_TYPES:
            start     = samples[i - 1] if i > 0 else 0
            end       = samples[i + 1] if i < len(samples) - 1 else n
            mid       = samples[i]
            seg_start = (mid + start) // 2
            seg_end   = (mid + end)   // 2
            label[seg_start:seg_end] = 1.0
    return sig, label

print("Loading training records (normal sinus rhythm)...")
train_segs = []
for r in TRAIN_RECORDS:
    sig, lbl = load_mitbih_record(r)
    train_segs.append(sig[lbl == 0])   # unsupervised training: normal beats only
    print(f"  {r}: {sig.shape[0]:,} samples  anomaly rate={lbl.mean():.1%}")

print("\nLoading test records (arrhythmia-heavy)...")
test_segs, test_lbls = [], []
for r in TEST_RECORDS:
    sig, lbl = load_mitbih_record(r)
    test_segs.append(sig)
    test_lbls.append(lbl)
    print(f"  {r}: {sig.shape[0]:,} samples  anomaly rate={lbl.mean():.1%}")

train_data  = np.concatenate(train_segs, axis=0)
test_data   = np.concatenate(test_segs,  axis=0)
test_labels = np.concatenate(test_lbls,  axis=0)

scaler      = StandardScaler()
train_data  = scaler.fit_transform(train_data).astype(np.float32)
test_data   = scaler.transform(test_data).astype(np.float32)

PROJECT_DIR = os.environ.get('PROJECT_DIR', os.getcwd())
os.makedirs(f'{PROJECT_DIR}/dataset/MITBIH', exist_ok=True)
np.save(f'{PROJECT_DIR}/dataset/MITBIH/MITBIH_train.npy',      train_data)
np.save(f'{PROJECT_DIR}/dataset/MITBIH/MITBIH_test.npy',       test_data)
np.save(f'{PROJECT_DIR}/dataset/MITBIH/MITBIH_test_label.npy', test_labels)

# Calibrate threshold: fraction of anomalous test samples in the combined set
ar_test = round(float(test_labels.sum()) / (len(train_data) + len(test_data)) * 100, 3)
print(f"\nMIT-BIH ready — train: {train_data.shape}  test: {test_data.shape}")
print(f"Test anomaly rate: {test_labels.mean():.1%}  →  anormly_ratio for test ≈ {ar_test}")

# %cd $PROJECT_DIR
# !python main.py --anormly_ratio 1.0      --num_epochs 10 --batch_size 256 --mode train --dataset MITBIH --data_path dataset/MITBIH --input_c 2 --output_c 2
# !python main.py --anormly_ratio {ar_test} --num_epochs 10 --batch_size 256 --mode test  --dataset MITBIH --data_path dataset/MITBIH --input_c 2 --output_c 2
# Out:
# Loading training records (normal sinus rhythm)...
#   100: 650,000 samples  anomaly rate=1.5%
#   101: 650,000 samples  anomaly rate=0.5%
#   103: 650,000 samples  anomaly rate=0.3%
#   105: 650,000 samples  anomaly rate=4.2%
#   112: 650,000 samples  anomaly rate=0.3%
#   122: 650,000 samples  anomaly rate=0.0%
#
# Loading test records (arrhythmia-heavy)...
#   200: 650,000 samples  anomaly rate=35.2%
#   207: 650,000 samples  anomaly rate=23.1%
